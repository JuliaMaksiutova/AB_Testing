# %% [markdown]
# ### Homework2

# %% [markdown]
# #### Ex001

# %% [markdown]
# ![Снимок экрана 2023-09-17 184109.png](data:image/png;base64,...)

# %% [markdown]
# <u>Гипотеза 1</u><br>
# Приобретение другог онлайн магазина<br>
# I - 5, C - 7, E - 8 = 280<br>
# <u>Гипотеза 2</u><br>
# Баннеры на таджикском языке<br>
# I - 3, C - 1, E - 8 = 24<br>
# <u>Гипотеза 3</u><br>
# Совместная промо-акция с РЖД<br>
# I - 6, C - 4, E - 5 = 120<br>

# %% [markdown]
# #### Ex002

# %% [markdown]
# ![Снимок экрана 2023-09-17 184115.png](data:image/png;base64,...)

# %% [markdown]
# <u>Гипотеза 1:</u><br>
# <div align = 'justify';>
# <p>Купить другой онлайн магазин (прецедент - приобретение X5 Болеро.ру URL: https://www.cnews.ru/news/top/vladelets_perekrestka_kupil_bolero_i_003_ru)</p>
# <p><u>Что делаем в каждой из групп:</u><br>
# Предлагаем пользователям группы "A" приобрести аналогичный товар на портале Ozon<br>
# Предлагаем пользователям группы "B" приобрести аналогичный товар с единоразовой преимией в баллах 5 % от общего баланса баллов и 15 % при условии офомрмления карты Ozon
# </p>
# <p><u>На каких пользователях тестируем:</u><br>
# Случайная равновеликая выборка из пользователей приобретаемой платформы
# <p><u>Метрики:</u><br>
# Total user - общее количество пользователей.<br>
# Conversion Rate - сколько пользователей совершили покупку.<br>
# </p>
# </div>
